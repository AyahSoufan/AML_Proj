# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
data_train=pd.read_csv("train.csv",header=0)
print(data_train[0:1])
length_train=data_train.shape
data_toxic=data_train.loc[:,['toxic']]
m_toxic=0
m_nontoxic=0
for i in range(length_train[0]):
    if (data_toxic.iloc[i,0]!=0):
        m_toxic+=1
for i in range(length_train[0]):
    if (data_toxic.iloc[i,0]==0):
        m_nontoxic+=1
X0=np.arange(2)
Y0=[m_toxic/length_train[0],m_nontoxic/length_train[0]]
name_list0=['Toxic','Non_toxic']
plt.bar(X0,Y0,width = 0.35,tick_label=name_list0)
plt.show()
# Out:
#                  id                                       comment_text  toxic  \
# 0  0000997932d777bf  Explanation\nWhy the edits made under my usern...      0
#
#    severe_toxic  obscene  threat  insult  identity_hate
# 0             0        0       0       0              0

# %%
data_severe_toxic=data_train.loc[:,['severe_toxic']]
m_severe_toxic=0
for i in range(length_train[0]):
    if (data_severe_toxic.iloc[i,0]!=0):
        m_severe_toxic+=1
print(m_severe_toxic)
# Out:
# 1595

# %%
data_obscene=data_train.loc[:,['obscene']]
m_obscene=0
for i in range(length_train[0]):
    if (data_obscene.iloc[i,0]!=0):
        m_obscene+=1
print(m_obscene)
# Out:
# 8449

# %%
data_threat=data_train.loc[:,['threat']]
m_threat=0
for i in range(length_train[0]):
    if (data_threat.iloc[i,0]!=0):
        m_threat+=1
print(m_threat)
# Out:
# 478

# %%
data_insult=data_train.loc[:,['insult']]
m_insult=0
for i in range(length_train[0]):
    if (data_insult.iloc[i,0]!=0):
        m_insult+=1
print(m_insult)
# Out:
# 7877

# %%
data_identity_hate =data_train.loc[:,['identity_hate']]
m_identity_hate=0
for i in range(length_train[0]):
    if (data_identity_hate .iloc[i,0]!=0):
        m_identity_hate +=1
print(m_identity_hate)
# Out:
# 1405

# %%
X=np.arange(6)
Y=[m_toxic,m_severe_toxic,m_obscene,m_threat,m_insult,m_identity_hate]
name_list=['Toxic','Severe_toxic','Obscene','Threat','Insult','Identity_hate']
plt.bar(X,Y,width = 0.45,tick_label=name_list)
plt.show()

# %%
toxic=m_toxic/length_train[0]
severe_toxic=m_severe_toxic/length_train[0]
obscene=m_obscene/length_train[0]
threat=m_threat/length_train[0]
insult=m_insult/length_train[0]
identity_hate=m_identity_hate/length_train[0]
Y1=[toxic,severe_toxic,obscene,threat,insult,identity_hate]
plt.bar(X,Y1,width = 0.45,tick_label=name_list)
plt.xlabel('Type of toxic')    
plt.ylabel('Percentage')
plt.show()

# %%
data_all_toxic=data_train.loc[:,['toxic','severe_toxic','obscene','threat','insult','identity_hate']]
data_all_length=data_all_toxic.shape
toxic_severe_toxic=0
toxic_obscene=0
toxic_threat=0
toxic_insult=0
toxic_identity_hate=0
for i in range(length_train[0]):
    if (data_all_toxic.iloc[i,0]==1 and data_all_toxic.iloc[i,1]==1):
        toxic_severe_toxic+=1
    elif (data_all_toxic.iloc[i,0]==1 and data_all_toxic.iloc[i,2]==1):
        toxic_obscene+=1
    elif (data_all_toxic.iloc[i,0]==1 and data_all_toxic.iloc[i,3]==1):
        toxic_threat+=1
    elif (data_all_toxic.iloc[i,0]==1 and data_all_toxic.iloc[i,4]==1):
        toxic_insult+=1
    elif (data_all_toxic.iloc[i,0]==1 and data_all_toxic.iloc[i,5]==1):
        toxic_identity_hate+=1
list_toxic=['Severe_toxic','Obscene','Threat','Insult','Identity_hate']
X2=np.arange(5)
Y2=[toxic_severe_toxic,toxic_obscene,toxic_threat,toxic_insult,toxic_identity_hate]
plt.bar(X2,Y2,width = 0.45,tick_label=list_toxic)
plt.xlabel('Type of toxic')    
plt.ylabel('If toxic, number of other types of toxic')
plt.show()

# %%
p_toxic_severe_toxic=toxic_severe_toxic/m_toxic
p_toxic_obscene=toxic_obscene/m_toxic
p_toxic_threat=toxic_threat/m_toxic
p_toxic_insult=toxic_insult/m_toxic
p_toxic_identity_hate=toxic_identity_hate/m_toxic
list_toxic=['Severe_toxic','Obscene','Threat','Insult','Identity_hate']
X2=np.arange(5)
Y2=[p_toxic_severe_toxic,p_toxic_obscene,p_toxic_threat,p_toxic_insult,p_toxic_identity_hate]
plt.bar(X2,Y2,width = 0.45,tick_label=list_toxic)
plt.xlabel('Type of toxic')    
plt.ylabel('If toxic, percentage of other types of toxic')
plt.show()

# %%
severe_toxic_obscene=0
severe_toxic_threat=0
severe_toxic_insult=0
severe_toxic_identity_hate=0
severe_toxic=0
for i in range(length_train[0]):
    if (data_all_toxic.iloc[i,1]==1 and data_all_toxic.iloc[i,2]==1):
        severe_toxic_obscene+=1
    elif (data_all_toxic.iloc[i,1]==1 and data_all_toxic.iloc[i,3]==1):
        severe_toxic_threat+=1
    elif (data_all_toxic.iloc[i,1]==1 and data_all_toxic.iloc[i,4]==1):
        severe_toxic_insult+=1
    elif (data_all_toxic.iloc[i,1]==1 and data_all_toxic.iloc[i,5]==1):
        severe_toxic_identity_hate+=1
    elif (data_all_toxic.iloc[i,1]==1 and data_all_toxic.iloc[i,0]==1):
        severe_toxic+=1
        
list_toxic=['Toxic','Obscene','Threat','Insult','Identity_hate']
X2=np.arange(5)
Y2=[severe_toxic,severe_toxic_obscene,severe_toxic_threat,severe_toxic_insult,severe_toxic_identity_hate]
plt.bar(X2,Y2,width = 0.45,tick_label=list_toxic)
plt.xlabel('Type of toxic')    
plt.ylabel('If severe_toxic, number of other types of toxic')
plt.show()

# %%
severe_toxic_obscene=0
severe_toxic_threat=0
severe_toxic_insult=0
severe_toxic_identity_hate=0
severe_toxic=0
for i in range(length_train[0]):
    if (data_all_toxic.iloc[i,1]==1 and data_all_toxic.iloc[i,2]==1):
        severe_toxic_obscene+=1
    elif (data_all_toxic.iloc[i,1]==1 and data_all_toxic.iloc[i,3]==1):
        severe_toxic_threat+=1
    elif (data_all_toxic.iloc[i,1]==1 and data_all_toxic.iloc[i,4]==1):
        severe_toxic_insult+=1
    elif (data_all_toxic.iloc[i,1]==1 and data_all_toxic.iloc[i,5]==1):
        severe_toxic_identity_hate+=1
    elif (data_all_toxic.iloc[i,1]==1 and data_all_toxic.iloc[i,0]==1):
        severe_toxic+=1
        
list_toxic=['Toxic','Obscene','Threat','Insult','Identity_hate']
X2=np.arange(5)
Y2=[severe_toxic/m_severe_toxic,severe_toxic_obscene/m_severe_toxic,severe_toxic_threat/m_severe_toxic,severe_toxic_insult/m_severe_toxic,severe_toxic_identity_hate/m_severe_toxic]
plt.bar(X2,Y2,width = 0.45,tick_label=list_toxic)
plt.xlabel('Type of toxic')    
plt.ylabel('If severe_toxic, percentage of other types of toxic')
plt.show()

# %%
obscene_toxic=0
obscene_toxic_severe=0
obscene_toxic_threat=0
obscene_toxic_insult=0
obscene_toxic_identity_hate=0

for i in range(length_train[0]):
    if (data_all_toxic.iloc[i,2]==1 and data_all_toxic.iloc[i,1]==1):
        obscene_toxic_severe+=1
    elif (data_all_toxic.iloc[i,2]==1 and data_all_toxic.iloc[i,3]==1):
        obscene_toxic_threat+=1
    elif (data_all_toxic.iloc[i,2]==1 and data_all_toxic.iloc[i,4]==1):
        obscene_toxic_insult+=1
    elif (data_all_toxic.iloc[i,2]==1 and data_all_toxic.iloc[i,5]==1):
        obscene_toxic_identity_hate+=1
    elif (data_all_toxic.iloc[i,2]==1 and data_all_toxic.iloc[i,0]==1):
        obscene_toxic+=1
        
list_toxic=['Toxic','Severe_toxic','Threat','Insult','Identity_hate']
X2=np.arange(5)
Y3=[obscene_toxic/m_obscene,obscene_toxic_severe/m_obscene,obscene_toxic_threat/m_obscene,obscene_toxic_insult/m_obscene,obscene_toxic_identity_hate/m_obscene]
plt.bar(X2,Y3,width = 0.45,tick_label=list_toxic)
plt.xlabel('Type of toxic')    
plt.ylabel('If obscene, percentage of other types of toxic')
plt.show()

# %%
threat_toxic=0
threat_toxic_severe=0
threat_toxic_obscene=0
threat_toxic_insult=0
threat_toxic_identity_hate=0

for i in range(length_train[0]):
    if (data_all_toxic.iloc[i,3]==1 and data_all_toxic.iloc[i,1]==1):
        threat_toxic_severe+=1
    elif (data_all_toxic.iloc[i,3]==1 and data_all_toxic.iloc[i,2]==1):
        threat_toxic_obscene+=1
    elif (data_all_toxic.iloc[i,3]==1 and data_all_toxic.iloc[i,4]==1):
        threat_toxic_insult+=1
    elif (data_all_toxic.iloc[i,3]==1 and data_all_toxic.iloc[i,5]==1):
        threat_toxic_identity_hate+=1
    elif (data_all_toxic.iloc[i,3]==1 and data_all_toxic.iloc[i,0]==1):
        threat_toxic+=1
        
list_toxic=['Toxic','Severe_toxic','Obscene','Insult','Identity_hate']
X2=np.arange(5)
Y3=[threat_toxic/m_threat,threat_toxic_severe/m_threat,threat_toxic_obscene/m_threat,threat_toxic_insult/m_threat,threat_toxic_identity_hate/m_threat]
plt.bar(X2,Y3,width = 0.45,tick_label=list_toxic)
plt.xlabel('Type of toxic')    
plt.ylabel('If threat, percentage of other types of toxic')
plt.show()

# %%
insult_toxic=0
insult_toxic_severe=0
insult_toxic_obscene=0
insult_toxic_threat=0
insult_toxic_identity_hate=0

for i in range(length_train[0]):
    if (data_all_toxic.iloc[i,4]==1 and data_all_toxic.iloc[i,1]==1):
        insult_toxic_severe+=1
    elif (data_all_toxic.iloc[i,4]==1 and data_all_toxic.iloc[i,2]==1):
        insult_toxic_obscene+=1
    elif (data_all_toxic.iloc[i,4]==1 and data_all_toxic.iloc[i,3]==1):
        insult_toxic_threat+=1
    elif (data_all_toxic.iloc[i,4]==1 and data_all_toxic.iloc[i,5]==1):
        insult_toxic_identity_hate+=1
    elif (data_all_toxic.iloc[i,4]==1 and data_all_toxic.iloc[i,0]==1):
        insult_toxic+=1
        
list_toxic=['Toxic','Severe_toxic','Obscene','Threat','Identity_hate']
X2=np.arange(5)
Y4=[insult_toxic/m_insult,insult_toxic_severe/m_insult,insult_toxic_obscene/m_insult,insult_toxic_threat/m_insult,insult_toxic_identity_hate/m_insult]
plt.bar(X2,Y4,width = 0.45,tick_label=list_toxic)
plt.xlabel('Type of toxic')    
plt.ylabel('If insult, percentage of other types of toxic')
plt.show()

# %%
identity_hate_toxic=0
identity_hate_toxic_severe=0
identity_hate_toxic_obscene=0
identity_hate_toxic_threat=0
identity_hate_toxic_insult=0

for i in range(length_train[0]):
    if (data_all_toxic.iloc[i,5]==1 and data_all_toxic.iloc[i,1]==1):
        identity_hate_toxic_severe+=1
    elif (data_all_toxic.iloc[i,5]==1 and data_all_toxic.iloc[i,2]==1):
        identity_hate_toxic_obscene+=1
    elif (data_all_toxic.iloc[i,5]==1 and data_all_toxic.iloc[i,3]==1):
        identity_hate_toxic_threat+=1
    elif (data_all_toxic.iloc[i,5]==1 and data_all_toxic.iloc[i,4]==1):
        identity_hate_toxic_insult+=1
    elif (data_all_toxic.iloc[i,5]==1 and data_all_toxic.iloc[i,0]==1):
        identity_hate_toxic+=1
        
list_toxic=['Toxic','Severe_toxic','Obscene','Threat','Insult']
X2=np.arange(5)
Y5=[identity_hate_toxic/m_identity_hate,identity_hate_toxic_severe/m_identity_hate,identity_hate_toxic_obscene/m_identity_hate,identity_hate_toxic_threat/m_identity_hate,identity_hate_toxic_insult/m_identity_hate]
plt.bar(X2,Y5,width = 0.45,tick_label=list_toxic)
plt.xlabel('Type of toxic')    
plt.ylabel('If identity_hate, percentage of other types of toxic')
plt.show()

# %%
df_correlations=data_all_toxic.corr()
#print(df_correlations)
data_all_toxic.corr()
# Out:
#                   toxic  severe_toxic   obscene    threat    insult  \
# toxic          1.000000      0.308619  0.676515  0.157058  0.647518
# severe_toxic   0.308619      1.000000  0.403014  0.123601  0.375807
# obscene        0.676515      0.403014  1.000000  0.141179  0.741272
# threat         0.157058      0.123601  0.141179  1.000000  0.150022
# insult         0.647518      0.375807  0.741272  0.150022  1.000000
# identity_hate  0.266009      0.201600  0.286867  0.115128  0.337736
#
#                identity_hate
# toxic               0.266009
# severe_toxic        0.201600
# obscene             0.286867
# threat              0.115128
# insult              0.337736
# identity_hate       1.000000

# %%
sns.heatmap(df_correlations, vmin=-0.8, vmax=0.8, center=0.0)
sns.plt.show()
